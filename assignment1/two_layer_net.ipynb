# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

#from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
# C = 3
# N = 4
# D = 5
# H = 2

# seed = np.random.RandomState(2)
# W1 = seed.choice(np.arange(-1, 1, 0.1), D * H).reshape(D, H)
# b1 = seed.choice(np.arange(-1, 1, 0.1), H)
# W2 = seed.choice(np.arange(-1, 1, 0.1), H * C).reshape(H, C)
# b2 = seed.choice(np.arange(-1, 1, 0.1), C)
# X = seed.choice(np.arange(-10, 10, 1), N * D).reshape(N, D)
# y = seed.choice(np.arange(C), N)
# print(X.shape, W1.shape, b1.shape, W2.shape, b2.shape, y.shape)
# print(X)
# print(W1)
# print(b1)
# print(W2)
# print(b2)
# print(y)

# print(X - np.max(X, axis=1).reshape(-1, 1))

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.80615009 -1.27035892 -0.69717262]
#  [-0.16510944 -1.18184578 -0.46691712]
#  [-0.50971743 -1.00735582 -0.84423417]
#  [-0.14800559 -0.48010906 -0.5228322 ]
#  [ 0.         -0.11816528 -0.14608217]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 0.09280987122142449

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %% [markdown]
# D = 4
# H = 10
# C = 3
# N = 5

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.7985612998927536e-13

# %%
# def sum_f(a, b):
#   return a + b

# def dot_f(X, W):
#   return X.dot(W)

# def mult_f(a, b):
#   return a * b

# def exp_f(a):
#   return np.exp(a)

# def div_f(a, b):
#   #assert 0 not in b
#   assert b != 0
#   return a / b

# def sum_d(a, b, arg):
#   if arg == 0:
#     return np.ones_like(a)
#   elif arg == 1:
#     return np.ones_like(b)
#   else:
#     raise
    
# def dot_d(X, W, arg):
#   if arg == 0:
#     return W
#   elif arg == 1:
#     return X
#   else:
#     raise
    
# def mult_d(a, b, arg):
#   if arg == 0:
#     return b
#   elif arg == 1:
#     return a
#   else:
#     raise
    
# def exp_d(a):
#   return np.exp(a)

# def div_d(a, b):
#   return -a / (b**2)



# def backprop(X, W, b):
#   '''/tested'''
#   r = dot_f(X, W) # 1
#   p = sum_f(r, b) # 2
#   k = mult_f(p, -1) # 3
#   h = exp_f(k) # 4
#   q = sum_f(h, 1) # 5
#   f = div_f(1, q) # 6
    
#   grad = {}

#   dq = div_d(1, q) * 1.0 # 6
#   dh = sum_d(h, 1, 0) * dq # 5
#   dk = exp_d(k) * dh # 4
#   dp = mult_d(p, -1, 0) * dk # 3
#   dr = sum_d(r, b, 0) * dp # 2
#   db = sum_d(r, b, 1) * dp # 2
#   dX = dot_d(X, W, 0) * dr # 1
#   dW = dot_d(X, W, 1) * dr # 1
  
#   grad['W'] = dW
#   grad['X'] = dX
#   grad['b'] = db
#   '''tested/'''
#   return f, grad

# X = np.array([-1, -2])
# W = np.array([2, -3])
# b = -3

# tmp = backprop(X, W, b)
# tmp

# %%
# a = np.array([
#     [0, 1, 2, 3],
#     [-3, 1, -2, 1],
#     [-9, 2, 2, 4]
# ])
# a1 = np.zeros_like(a)
# a1[a>0] = 1
# a1 * a

# %%
# def sum_f(a, b):
#   return a + b

# def dot_f(X, W):
#   return X.dot(W)

# def mult_f(a, b):
#   return a * b

# def exp_f(a):
#   return np.exp(a)

# def div_f(a, b):
#   #assert 0 not in b
#   assert b != 0
#   return a / b

# def sum_d(a, b, arg):
#   if arg == 0:
#     return np.ones_like(a)
#   elif arg == 1:
#     return np.ones_like(b)
#   else:
#     raise
    
# def dot_d(X, W, arg):
#   if arg == 0:
#     return W
#   elif arg == 1:
#     return X
#   else:
#     raise
    
# def mult_d(a, b, arg):
#   if arg == 0:
#     return b
#   elif arg == 1:
#     return a
#   else:
#     raise
    
# def exp_d(a):
#   return np.exp(a)

# def div_d(a, b):
#   return -a / (b**2)

# def backprop(X, W1, b1, W2, b2):

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
# H = b1.shape[0]
#     C = b2.shape[0]
    
#     dW2_parentheses = np.exp(scores) / np.sum(np.exp(scores), axis=1).reshape(-1, 1) # (N, C)
#     dW2_parentheses[true_class_idx[:, 0], true_class_idx[:, 1]] -= 1 
#     dW2 = A1.T.dot(dW2_parentheses) # (H, C): (H, N)x(N, C)
#     dW2 += 2 * reg * W2
#     dW2 /= N
    
#     db2 = -1 + np.exp(scores) / np.sum(np.exp(scores), axis=1).reshape(-1, 1) # (N, C)
#     db2 = db2.T.dot(np.ones_like(y).reshape(-1, 1)) # (C,1)
    
#     dDot2 = dW2_parentheses.dot(W2.T) # (N, H) = (N, C)x(C,H)
#     dRelu = np.zeros_like(dDot2) # (N, H)
#     dRelu[dDot2 > 0] = 1
#     dSum = dRelu * dDot2 # (N, H)
#     db1 = dSum.T.dot(np.ones_like(y).reshape(-1, 1)) # (H,1)
#     dDot1 = dSum # (N,H)
#     dW1 = X.T.dot(dDot1) # need: (D,H): X: (N, D) dDot1: (N, H);
#     dW1 += 2 * reg * W1
    
#     grads['W1'] = dW1
#     grads['b1'] = db1
#     grads['W2'] = dW2
#     grads['b2'] = db2

# %% [markdown]
# D = 4
# H = 10
# C = 3
# N = 5

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.999856e-09
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447646e-11

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.01714960793873207

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 
#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# np.seterr(all='print')

results = {}
best_val = -1
batch_size = 256
num_iters = 2000

learning_rates = [1e-3, 5e-4, 1e-4] # default: 1e-3
regularization_strengths = [1e-6, 5e-6, 1e-5, 5e-5] # default: 5e-6
learning_rate_decays = [0.95, 0.99, 0.999] # default: 0.95

input_size = 32 * 32 * 3
hidden_size = 150
num_classes = 10

nets = {}

i = 0
for decay in learning_rate_decays:
    for lr in learning_rates:
        for C in regularization_strengths:
            print('decay {}, lr {}, C {}'.format(decay, lr, C))
            print('Done {:2} out of {}'.format(i+1, len(learning_rates)*len(regularization_strengths)*len(learning_rate_decays)))
            
            # train
            net = TwoLayerNet(input_size, hidden_size, num_classes)
            net.train(X_train, y_train, X_val, y_val, num_iters=num_iters, 
                      batch_size=batch_size, learning_rate=lr, 
                      learning_rate_decay=decay,reg=C, verbose=True)
            # predict
            y_train_pred = net.predict(X_train)
            y_val_pred = net.predict(X_val)
            # scoring
            train_score = np.mean(y_train == y_train_pred)
            val_score = np.mean(y_val == y_val_pred)
            # store results
            results[(decay, lr, C)] = (train_score, val_score)
            nets[(decay, lr, C)] = net
            
            i += 1

sorted_results = sorted(results.items(), key=lambda x: x[1][1]) # by val score
best_params = sorted_results[-1][0]
best_val = sorted_results[-1][1][1]
best_net = nets[best_params]
print(best_net.lr_decay, best_net.lr, best_net.C)
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################

# Print out results.
for decay, lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(decay, lr, reg)]
    print('decay %e lr %e reg %e train accuracy: %f val accuracy: %f' % (
                decay, lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# decay 0.95, lr 0.001, C 1e-06
# Done  1 out of 36
# iteration 0 / 2000: loss 2.302561
# iteration 100 / 2000: loss 1.911294
# iteration 200 / 2000: loss 1.710050
# iteration 300 / 2000: loss 1.678422
# iteration 400 / 2000: loss 1.544626
# iteration 500 / 2000: loss 1.440984
# iteration 600 / 2000: loss 1.635463
# iteration 700 / 2000: loss 1.537214
# iteration 800 / 2000: loss 1.367047
# iteration 900 / 2000: loss 1.344555
# iteration 1000 / 2000: loss 1.455256
# iteration 1100 / 2000: loss 1.349425
# iteration 1200 / 2000: loss 1.299893
# iteration 1300 / 2000: loss 1.308993
# iteration 1400 / 2000: loss 1.310225
# iteration 1500 / 2000: loss 1.396936
# iteration 1600 / 2000: loss 1.337578
# iteration 1700 / 2000: loss 1.177217
# iteration 1800 / 2000: loss 1.159850
# iteration 1900 / 2000: loss 1.117241
# decay 0.95, lr 0.001, C 5e-06
# Done  2 out of 36
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 1.892045
# iteration 200 / 2000: loss 1.680426
# iteration 300 / 2000: loss 1.629801
# iteration 400 / 2000: loss 1.653934
# iteration 500 / 2000: loss 1.506004
# iteration 600 / 2000: loss 1.443495
# iteration 700 / 2000: loss 1.494245
# iteration 800 / 2000: loss 1.328013
# iteration 900 / 2000: loss 1.293304
# iteration 1000 / 2000: loss 1.389958
# iteration 1100 / 2000: loss 1.309461
# iteration 1200 / 2000: loss 1.264364
# iteration 1300 / 2000: loss 1.345132
# iteration 1400 / 2000: loss 1.444633
# iteration 1500 / 2000: loss 1.355309
# iteration 1600 / 2000: loss 1.205469
# iteration 1700 / 2000: loss 1.083083
# iteration 1800 / 2000: loss 1.250198
# iteration 1900 / 2000: loss 1.310225
# decay 0.95, lr 0.001, C 1e-05
# Done  3 out of 36
# iteration 0 / 2000: loss 2.302568
# iteration 100 / 2000: loss 1.877787
# iteration 200 / 2000: loss 1.658289
# iteration 300 / 2000: loss 1.688274
# iteration 400 / 2000: loss 1.516107
# iteration 500 / 2000: loss 1.495228
# iteration 600 / 2000: loss 1.465677
# iteration 700 / 2000: loss 1.524305
# iteration 800 / 2000: loss 1.464894
# iteration 900 / 2000: loss 1.342117
# iteration 1000 / 2000: loss 1.423396
# iteration 1100 / 2000: loss 1.455046
# iteration 1200 / 2000: loss 1.338356
# iteration 1300 / 2000: loss 1.408255
# iteration 1400 / 2000: loss 1.405572
# iteration 1500 / 2000: loss 1.236903
# iteration 1600 / 2000: loss 1.167705
# iteration 1700 / 2000: loss 1.250556
# iteration 1800 / 2000: loss 1.307560
# iteration 1900 / 2000: loss 1.263383
# decay 0.95, lr 0.001, C 5e-05
# Done  4 out of 36
# iteration 0 / 2000: loss 2.302616
# iteration 100 / 2000: loss 1.936366
# iteration 200 / 2000: loss 1.680654
# iteration 300 / 2000: loss 1.694580
# iteration 400 / 2000: loss 1.537113
# iteration 500 / 2000: loss 1.489281
# iteration 600 / 2000: loss 1.514513
# iteration 700 / 2000: loss 1.488017
# iteration 800 / 2000: loss 1.371376
# iteration 900 / 2000: loss 1.384151
# iteration 1000 / 2000: loss 1.396313
# iteration 1100 / 2000: loss 1.333345
# iteration 1200 / 2000: loss 1.328567
# iteration 1300 / 2000: loss 1.256510
# iteration 1400 / 2000: loss 1.307580
# iteration 1500 / 2000: loss 1.245895
# iteration 1600 / 2000: loss 1.150618
# iteration 1700 / 2000: loss 1.255474
# iteration 1800 / 2000: loss 1.207806
# iteration 1900 / 2000: loss 1.233672
# decay 0.95, lr 0.0005, C 1e-06
# Done  5 out of 36
# iteration 0 / 2000: loss 2.302532
# iteration 100 / 2000: loss 2.098109
# iteration 200 / 2000: loss 1.952876
# iteration 300 / 2000: loss 1.725857
# iteration 400 / 2000: loss 1.838486
# iteration 500 / 2000: loss 1.601294
# iteration 600 / 2000: loss 1.629375
# iteration 700 / 2000: loss 1.524608
# iteration 800 / 2000: loss 1.457248
# iteration 900 / 2000: loss 1.555823
# iteration 1000 / 2000: loss 1.527909
# iteration 1100 / 2000: loss 1.535378
# iteration 1200 / 2000: loss 1.475525
# iteration 1300 / 2000: loss 1.361757
# iteration 1400 / 2000: loss 1.457783
# iteration 1500 / 2000: loss 1.410093
# iteration 1600 / 2000: loss 1.484533
# iteration 1700 / 2000: loss 1.272404
# iteration 1800 / 2000: loss 1.288272
# iteration 1900 / 2000: loss 1.221176
# decay 0.95, lr 0.0005, C 5e-06
# Done  6 out of 36
# iteration 0 / 2000: loss 2.302537
# iteration 100 / 2000: loss 2.020605
# iteration 200 / 2000: loss 1.912714
# iteration 300 / 2000: loss 1.790526
# iteration 400 / 2000: loss 1.689933
# iteration 500 / 2000: loss 1.751681
# iteration 600 / 2000: loss 1.538688
# iteration 700 / 2000: loss 1.484671
# iteration 800 / 2000: loss 1.595776
# iteration 900 / 2000: loss 1.569540
# iteration 1000 / 2000: loss 1.474252
# iteration 1100 / 2000: loss 1.617799
# iteration 1200 / 2000: loss 1.561616
# iteration 1300 / 2000: loss 1.593544
# iteration 1400 / 2000: loss 1.269029
# iteration 1500 / 2000: loss 1.534414
# iteration 1600 / 2000: loss 1.452235
# iteration 1700 / 2000: loss 1.327879
# iteration 1800 / 2000: loss 1.301876
# iteration 1900 / 2000: loss 1.408965
# decay 0.95, lr 0.0005, C 1e-05
# Done  7 out of 36
# iteration 0 / 2000: loss 2.302580
# iteration 100 / 2000: loss 2.105378
# iteration 200 / 2000: loss 1.948423
# iteration 300 / 2000: loss 1.705836
# iteration 400 / 2000: loss 1.666029
# iteration 500 / 2000: loss 1.694447
# iteration 600 / 2000: loss 1.672092
# iteration 700 / 2000: loss 1.501086
# iteration 800 / 2000: loss 1.697738
# iteration 900 / 2000: loss 1.557031
# iteration 1000 / 2000: loss 1.484363
# iteration 1100 / 2000: loss 1.392497
# iteration 1200 / 2000: loss 1.478730
# iteration 1300 / 2000: loss 1.424116
# iteration 1400 / 2000: loss 1.369604
# iteration 1500 / 2000: loss 1.328737
# iteration 1600 / 2000: loss 1.409783
# iteration 1700 / 2000: loss 1.442083
# iteration 1800 / 2000: loss 1.454659
# iteration 1900 / 2000: loss 1.307534
# decay 0.95, lr 0.0005, C 5e-05
# Done  8 out of 36
# iteration 0 / 2000: loss 2.302605
# iteration 100 / 2000: loss 2.079899
# iteration 200 / 2000: loss 1.870713
# iteration 300 / 2000: loss 1.895943
# iteration 400 / 2000: loss 1.700811
# iteration 500 / 2000: loss 1.658371
# iteration 600 / 2000: loss 1.584820
# iteration 700 / 2000: loss 1.522041
# iteration 800 / 2000: loss 1.652031
# iteration 900 / 2000: loss 1.575331
# iteration 1000 / 2000: loss 1.654681
# iteration 1100 / 2000: loss 1.480955
# iteration 1200 / 2000: loss 1.482325
# iteration 1300 / 2000: loss 1.422860
# iteration 1400 / 2000: loss 1.359273
# iteration 1500 / 2000: loss 1.323727
# iteration 1600 / 2000: loss 1.394427
# iteration 1700 / 2000: loss 1.473342
# iteration 1800 / 2000: loss 1.200609
# iteration 1900 / 2000: loss 1.300580
# decay 0.95, lr 0.0001, C 1e-06
# Done  9 out of 36
# iteration 0 / 2000: loss 2.302557
# iteration 100 / 2000: loss 2.300328
# iteration 200 / 2000: loss 2.274094
# iteration 300 / 2000: loss 2.237270
# iteration 400 / 2000: loss 2.103617
# iteration 500 / 2000: loss 2.078064
# iteration 600 / 2000: loss 1.983363
# iteration 700 / 2000: loss 2.025092
# iteration 800 / 2000: loss 2.018390
# iteration 900 / 2000: loss 1.908572
# iteration 1000 / 2000: loss 1.868329
# iteration 1100 / 2000: loss 1.861252
# iteration 1200 / 2000: loss 1.847723
# iteration 1300 / 2000: loss 1.897923
# iteration 1400 / 2000: loss 1.911778
# iteration 1500 / 2000: loss 1.833081
# iteration 1600 / 2000: loss 1.656831
# iteration 1700 / 2000: loss 1.757763
# iteration 1800 / 2000: loss 1.730775
# iteration 1900 / 2000: loss 1.719159
# decay 0.95, lr 0.0001, C 5e-06
# Done 10 out of 36
# iteration 0 / 2000: loss 2.302568
# iteration 100 / 2000: loss 2.301031
# iteration 200 / 2000: loss 2.292061
# iteration 300 / 2000: loss 2.214460
# iteration 400 / 2000: loss 2.140565
# iteration 500 / 2000: loss 2.102240
# iteration 600 / 2000: loss 2.006955
# iteration 700 / 2000: loss 1.893873
# iteration 800 / 2000: loss 1.966899
# iteration 900 / 2000: loss 1.933531
# iteration 1000 / 2000: loss 1.921465
# iteration 1100 / 2000: loss 1.923167
# iteration 1200 / 2000: loss 1.885609
# iteration 1300 / 2000: loss 1.850933
# iteration 1400 / 2000: loss 1.792997
# iteration 1500 / 2000: loss 1.779304
# iteration 1600 / 2000: loss 1.797402
# iteration 1700 / 2000: loss 1.616474
# iteration 1800 / 2000: loss 1.676260
# iteration 1900 / 2000: loss 1.722308
# decay 0.95, lr 0.0001, C 1e-05
# Done 11 out of 36
# iteration 0 / 2000: loss 2.302605
# iteration 100 / 2000: loss 2.301184
# iteration 200 / 2000: loss 2.289758
# iteration 300 / 2000: loss 2.247382
# iteration 400 / 2000: loss 2.131246
# iteration 500 / 2000: loss 2.113172
# iteration 600 / 2000: loss 2.025826
# iteration 700 / 2000: loss 2.004457
# iteration 800 / 2000: loss 1.949224
# iteration 900 / 2000: loss 1.945480
# iteration 1000 / 2000: loss 1.878333
# iteration 1100 / 2000: loss 1.950307
# iteration 1200 / 2000: loss 1.791981
# iteration 1300 / 2000: loss 1.844398
# iteration 1400 / 2000: loss 1.747416
# iteration 1500 / 2000: loss 1.717257
# iteration 1600 / 2000: loss 1.715549
# iteration 1700 / 2000: loss 1.704104
# iteration 1800 / 2000: loss 1.746987
# iteration 1900 / 2000: loss 1.716199
# decay 0.95, lr 0.0001, C 5e-05
# Done 12 out of 36
# iteration 0 / 2000: loss 2.302562
# iteration 100 / 2000: loss 2.301533
# iteration 200 / 2000: loss 2.290889
# iteration 300 / 2000: loss 2.210826
# iteration 400 / 2000: loss 2.113074
# iteration 500 / 2000: loss 2.070732
# iteration 600 / 2000: loss 2.024287
# iteration 700 / 2000: loss 1.997633
# iteration 800 / 2000: loss 1.927657
# iteration 900 / 2000: loss 1.920764
# iteration 1000 / 2000: loss 1.933094
# iteration 1100 / 2000: loss 1.829439
# iteration 1200 / 2000: loss 1.773619
# iteration 1300 / 2000: loss 1.783733
# iteration 1400 / 2000: loss 1.846969
# iteration 1500 / 2000: loss 1.802280
# iteration 1600 / 2000: loss 1.727248
# iteration 1700 / 2000: loss 1.905388
# iteration 1800 / 2000: loss 1.697751
# iteration 1900 / 2000: loss 1.769887
# decay 0.99, lr 0.001, C 1e-06
# Done 13 out of 36
# iteration 0 / 2000: loss 2.302581
# iteration 100 / 2000: loss 1.783472
# iteration 200 / 2000: loss 1.765500
# iteration 300 / 2000: loss 1.665614
# iteration 400 / 2000: loss 1.535217
# iteration 500 / 2000: loss 1.538951
# iteration 600 / 2000: loss 1.384295
# iteration 700 / 2000: loss 1.377542
# iteration 800 / 2000: loss 1.355925
# iteration 900 / 2000: loss 1.453964
# iteration 1000 / 2000: loss 1.347777
# iteration 1100 / 2000: loss 1.248367
# iteration 1200 / 2000: loss 1.432319
# iteration 1300 / 2000: loss 1.383878
# iteration 1400 / 2000: loss 1.383696
# iteration 1500 / 2000: loss 1.217234
# iteration 1600 / 2000: loss 1.299425
# iteration 1700 / 2000: loss 1.307080
# iteration 1800 / 2000: loss 1.223557
# iteration 1900 / 2000: loss 1.188263
# decay 0.99, lr 0.001, C 5e-06
# Done 14 out of 36
# iteration 0 / 2000: loss 2.302615
# iteration 100 / 2000: loss 1.899450
# iteration 200 / 2000: loss 1.706617
# iteration 300 / 2000: loss 1.676884
# iteration 400 / 2000: loss 1.514543
# iteration 500 / 2000: loss 1.492864
# iteration 600 / 2000: loss 1.512239
# iteration 700 / 2000: loss 1.530972
# iteration 800 / 2000: loss 1.440057
# iteration 900 / 2000: loss 1.360399
# iteration 1000 / 2000: loss 1.388007
# iteration 1100 / 2000: loss 1.429570
# iteration 1200 / 2000: loss 1.400021
# iteration 1300 / 2000: loss 1.346497
# iteration 1400 / 2000: loss 1.335681
# iteration 1500 / 2000: loss 1.267359
# iteration 1600 / 2000: loss 1.301793
# iteration 1700 / 2000: loss 1.329279
# iteration 1800 / 2000: loss 1.343986
# iteration 1900 / 2000: loss 1.264167
# decay 0.99, lr 0.001, C 1e-05
# Done 15 out of 36
# iteration 0 / 2000: loss 2.302619
# iteration 100 / 2000: loss 1.920212
# iteration 200 / 2000: loss 1.695507
# iteration 300 / 2000: loss 1.606565
# iteration 400 / 2000: loss 1.632823
# iteration 500 / 2000: loss 1.408872
# iteration 600 / 2000: loss 1.485783
# iteration 700 / 2000: loss 1.454535
# iteration 800 / 2000: loss 1.463298
# iteration 900 / 2000: loss 1.242470
# iteration 1000 / 2000: loss 1.416683
# iteration 1100 / 2000: loss 1.356904
# iteration 1200 / 2000: loss 1.360801
# iteration 1300 / 2000: loss 1.244053
# iteration 1400 / 2000: loss 1.168223
# iteration 1500 / 2000: loss 1.380451
# iteration 1600 / 2000: loss 1.357353
# iteration 1700 / 2000: loss 1.336072
# iteration 1800 / 2000: loss 1.363819
# iteration 1900 / 2000: loss 1.300287
# decay 0.99, lr 0.001, C 5e-05
# Done 16 out of 36
# iteration 0 / 2000: loss 2.302606
# iteration 100 / 2000: loss 1.884195
# iteration 200 / 2000: loss 1.698791
# iteration 300 / 2000: loss 1.624106
# iteration 400 / 2000: loss 1.543649
# iteration 500 / 2000: loss 1.381018
# iteration 600 / 2000: loss 1.537145
# iteration 700 / 2000: loss 1.428551
# iteration 800 / 2000: loss 1.398968
# iteration 900 / 2000: loss 1.419352
# iteration 1000 / 2000: loss 1.309389
# iteration 1100 / 2000: loss 1.372188
# iteration 1200 / 2000: loss 1.301472
# iteration 1300 / 2000: loss 1.286220
# iteration 1400 / 2000: loss 1.307294
# iteration 1500 / 2000: loss 1.371874
# iteration 1600 / 2000: loss 1.219131
# iteration 1700 / 2000: loss 1.231603
# iteration 1800 / 2000: loss 1.311324
# iteration 1900 / 2000: loss 1.190288
# decay 0.99, lr 0.0005, C 1e-06
# Done 17 out of 36
# iteration 0 / 2000: loss 2.302571
# iteration 100 / 2000: loss 2.016141
# iteration 200 / 2000: loss 1.850648
# iteration 300 / 2000: loss 1.862561
# iteration 400 / 2000: loss 1.793365
# iteration 500 / 2000: loss 1.678117
# iteration 600 / 2000: loss 1.648441
# iteration 700 / 2000: loss 1.593037
# iteration 800 / 2000: loss 1.598756
# iteration 900 / 2000: loss 1.558763
# iteration 1000 / 2000: loss 1.578057
# iteration 1100 / 2000: loss 1.463823
# iteration 1200 / 2000: loss 1.553187
# iteration 1300 / 2000: loss 1.359333
# iteration 1400 / 2000: loss 1.388526
# iteration 1500 / 2000: loss 1.455108
# iteration 1600 / 2000: loss 1.421882
# iteration 1700 / 2000: loss 1.305678
# iteration 1800 / 2000: loss 1.358246
# iteration 1900 / 2000: loss 1.253228
# decay 0.99, lr 0.0005, C 5e-06
# Done 18 out of 36
# iteration 0 / 2000: loss 2.302641
# iteration 100 / 2000: loss 2.071594
# iteration 200 / 2000: loss 1.891284
# iteration 300 / 2000: loss 1.694572
# iteration 400 / 2000: loss 1.686018
# iteration 500 / 2000: loss 1.603184
# iteration 600 / 2000: loss 1.557192
# iteration 700 / 2000: loss 1.583924
# iteration 800 / 2000: loss 1.470117
# iteration 900 / 2000: loss 1.496611
# iteration 1000 / 2000: loss 1.454241
# iteration 1100 / 2000: loss 1.414352
# iteration 1200 / 2000: loss 1.358108
# iteration 1300 / 2000: loss 1.372124
# iteration 1400 / 2000: loss 1.339429
# iteration 1500 / 2000: loss 1.399686
# iteration 1600 / 2000: loss 1.359675
# iteration 1700 / 2000: loss 1.395683
# iteration 1800 / 2000: loss 1.336964
# iteration 1900 / 2000: loss 1.364376
# decay 0.99, lr 0.0005, C 1e-05
# Done 19 out of 36
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.106321
# iteration 200 / 2000: loss 1.823594
# iteration 300 / 2000: loss 1.771782
# iteration 400 / 2000: loss 1.826497
# iteration 500 / 2000: loss 1.661861
# iteration 600 / 2000: loss 1.640736
# iteration 700 / 2000: loss 1.609375
# iteration 800 / 2000: loss 1.666675
# iteration 900 / 2000: loss 1.456395
# iteration 1000 / 2000: loss 1.472132
# iteration 1100 / 2000: loss 1.472798
# iteration 1200 / 2000: loss 1.474178
# iteration 1300 / 2000: loss 1.463608
# iteration 1400 / 2000: loss 1.325627
# iteration 1500 / 2000: loss 1.360717
# iteration 1600 / 2000: loss 1.362800
# iteration 1700 / 2000: loss 1.394230
# iteration 1800 / 2000: loss 1.395110
# iteration 1900 / 2000: loss 1.321473
# decay 0.99, lr 0.0005, C 5e-05
# Done 20 out of 36
# iteration 0 / 2000: loss 2.302580
# iteration 100 / 2000: loss 2.056543
# iteration 200 / 2000: loss 1.921313
# iteration 300 / 2000: loss 1.803517
# iteration 400 / 2000: loss 1.758722
# iteration 500 / 2000: loss 1.624093
# iteration 600 / 2000: loss 1.624847
# iteration 700 / 2000: loss 1.542907
# iteration 800 / 2000: loss 1.520501
# iteration 900 / 2000: loss 1.424149
# iteration 1000 / 2000: loss 1.471298
# iteration 1100 / 2000: loss 1.542534
# iteration 1200 / 2000: loss 1.488065
# iteration 1300 / 2000: loss 1.581113
# iteration 1400 / 2000: loss 1.316059
# iteration 1500 / 2000: loss 1.448211
# iteration 1600 / 2000: loss 1.348155
# iteration 1700 / 2000: loss 1.474766
# iteration 1800 / 2000: loss 1.508223
# iteration 1900 / 2000: loss 1.263354
# decay 0.99, lr 0.0001, C 1e-06
# Done 21 out of 36
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.300773
# iteration 200 / 2000: loss 2.277254
# iteration 300 / 2000: loss 2.242615
# iteration 400 / 2000: loss 2.147241
# iteration 500 / 2000: loss 2.015503
# iteration 600 / 2000: loss 2.065238
# iteration 700 / 2000: loss 2.052073
# iteration 800 / 2000: loss 1.963679
# iteration 900 / 2000: loss 1.851800
# iteration 1000 / 2000: loss 1.924012
# iteration 1100 / 2000: loss 1.851238
# iteration 1200 / 2000: loss 1.885669
# iteration 1300 / 2000: loss 1.731453
# iteration 1400 / 2000: loss 1.798244
# iteration 1500 / 2000: loss 1.787922
# iteration 1600 / 2000: loss 1.799509
# iteration 1700 / 2000: loss 1.787363
# iteration 1800 / 2000: loss 1.722788
# iteration 1900 / 2000: loss 1.751008
# decay 0.99, lr 0.0001, C 5e-06
# Done 22 out of 36
# iteration 0 / 2000: loss 2.302574
# iteration 100 / 2000: loss 2.300901
# iteration 200 / 2000: loss 2.283166
# iteration 300 / 2000: loss 2.203996
# iteration 400 / 2000: loss 2.126594
# iteration 500 / 2000: loss 2.134530
# iteration 600 / 2000: loss 2.023821
# iteration 700 / 2000: loss 1.975739
# iteration 800 / 2000: loss 1.909450
# iteration 900 / 2000: loss 1.935053
# iteration 1000 / 2000: loss 1.881890
# iteration 1100 / 2000: loss 1.836120
# iteration 1200 / 2000: loss 1.761619
# iteration 1300 / 2000: loss 1.779501
# iteration 1400 / 2000: loss 1.792567
# iteration 1500 / 2000: loss 1.768305
# iteration 1600 / 2000: loss 1.752443
# iteration 1700 / 2000: loss 1.743384
# iteration 1800 / 2000: loss 1.808201
# iteration 1900 / 2000: loss 1.714198
# decay 0.99, lr 0.0001, C 1e-05
# Done 23 out of 36
# iteration 0 / 2000: loss 2.302543
# iteration 100 / 2000: loss 2.300759
# iteration 200 / 2000: loss 2.285527
# iteration 300 / 2000: loss 2.182622
# iteration 400 / 2000: loss 2.125083
# iteration 500 / 2000: loss 2.114405
# iteration 600 / 2000: loss 1.956938
# iteration 700 / 2000: loss 2.004663
# iteration 800 / 2000: loss 1.891944
# iteration 900 / 2000: loss 1.863169
# iteration 1000 / 2000: loss 1.855643
# iteration 1100 / 2000: loss 1.941388
# iteration 1200 / 2000: loss 1.836463
# iteration 1300 / 2000: loss 1.787727
# iteration 1400 / 2000: loss 1.852214
# iteration 1500 / 2000: loss 1.890546
# iteration 1600 / 2000: loss 1.659713
# iteration 1700 / 2000: loss 1.703349
# iteration 1800 / 2000: loss 1.782651
# iteration 1900 / 2000: loss 1.668618
# decay 0.99, lr 0.0001, C 5e-05
# Done 24 out of 36
# iteration 0 / 2000: loss 2.302602
# iteration 100 / 2000: loss 2.301329
# iteration 200 / 2000: loss 2.284035
# iteration 300 / 2000: loss 2.221139
# iteration 400 / 2000: loss 2.112681
# iteration 500 / 2000: loss 2.082090
# iteration 600 / 2000: loss 2.022558
# iteration 700 / 2000: loss 1.964283
# iteration 800 / 2000: loss 1.886926
# iteration 900 / 2000: loss 1.833132
# iteration 1000 / 2000: loss 1.916915
# iteration 1100 / 2000: loss 1.865278
# iteration 1200 / 2000: loss 1.913377
# iteration 1300 / 2000: loss 1.779837
# iteration 1400 / 2000: loss 1.732577
# iteration 1500 / 2000: loss 1.846202
# iteration 1600 / 2000: loss 1.827546
# iteration 1700 / 2000: loss 1.701895
# iteration 1800 / 2000: loss 1.792068
# iteration 1900 / 2000: loss 1.762796
# decay 0.999, lr 0.001, C 1e-06
# Done 25 out of 36
# iteration 0 / 2000: loss 2.302546
# iteration 100 / 2000: loss 1.921307
# iteration 200 / 2000: loss 1.666880
# iteration 300 / 2000: loss 1.605175
# iteration 400 / 2000: loss 1.430342
# iteration 500 / 2000: loss 1.524216
# iteration 600 / 2000: loss 1.523126
# iteration 700 / 2000: loss 1.464081
# iteration 800 / 2000: loss 1.475463
# iteration 900 / 2000: loss 1.548200
# iteration 1000 / 2000: loss 1.302974
# iteration 1100 / 2000: loss 1.324880
# iteration 1200 / 2000: loss 1.334009
# iteration 1300 / 2000: loss 1.314277
# iteration 1400 / 2000: loss 1.248250
# iteration 1500 / 2000: loss 1.438418
# iteration 1600 / 2000: loss 1.273093
# iteration 1700 / 2000: loss 1.387286
# iteration 1800 / 2000: loss 1.214068
# iteration 1900 / 2000: loss 1.176587
# decay 0.999, lr 0.001, C 5e-06
# Done 26 out of 36
# iteration 0 / 2000: loss 2.302596
# iteration 100 / 2000: loss 1.876140
# iteration 200 / 2000: loss 1.817041
# iteration 300 / 2000: loss 1.580920
# iteration 400 / 2000: loss 1.604584
# iteration 500 / 2000: loss 1.589800
# iteration 600 / 2000: loss 1.493449
# iteration 700 / 2000: loss 1.366101
# iteration 800 / 2000: loss 1.407976
# iteration 900 / 2000: loss 1.361105
# iteration 1000 / 2000: loss 1.349799
# iteration 1100 / 2000: loss 1.361147
# iteration 1200 / 2000: loss 1.180757
# iteration 1300 / 2000: loss 1.211604
# iteration 1400 / 2000: loss 1.172100
# iteration 1500 / 2000: loss 1.294620
# iteration 1600 / 2000: loss 1.221719
# iteration 1700 / 2000: loss 1.219526
# iteration 1800 / 2000: loss 1.125531
# iteration 1900 / 2000: loss 1.263889
# decay 0.999, lr 0.001, C 1e-05
# Done 27 out of 36
# iteration 0 / 2000: loss 2.302591
# iteration 100 / 2000: loss 1.941221
# iteration 200 / 2000: loss 1.713470
# iteration 300 / 2000: loss 1.619204
# iteration 400 / 2000: loss 1.666714
# iteration 500 / 2000: loss 1.493904
# iteration 600 / 2000: loss 1.507695
# iteration 700 / 2000: loss 1.481519
# iteration 800 / 2000: loss 1.341455
# iteration 900 / 2000: loss 1.406908
# iteration 1000 / 2000: loss 1.394237
# iteration 1100 / 2000: loss 1.693929
# iteration 1200 / 2000: loss 1.433961
# iteration 1300 / 2000: loss 1.270942
# iteration 1400 / 2000: loss 1.353897
# iteration 1500 / 2000: loss 1.192365
# iteration 1600 / 2000: loss 1.237306
# iteration 1700 / 2000: loss 1.127459
# iteration 1800 / 2000: loss 1.317944
# iteration 1900 / 2000: loss 1.234458
# decay 0.999, lr 0.001, C 5e-05
# Done 28 out of 36
# iteration 0 / 2000: loss 2.302578
# iteration 100 / 2000: loss 1.859973
# iteration 200 / 2000: loss 1.693279
# iteration 300 / 2000: loss 1.564361
# iteration 400 / 2000: loss 1.635974
# iteration 500 / 2000: loss 1.652777
# iteration 600 / 2000: loss 1.557543
# iteration 700 / 2000: loss 1.552837
# iteration 800 / 2000: loss 1.417169
# iteration 900 / 2000: loss 1.422346
# iteration 1000 / 2000: loss 1.366362
# iteration 1100 / 2000: loss 1.460819
# iteration 1200 / 2000: loss 1.365594
# iteration 1300 / 2000: loss 1.281675
# iteration 1400 / 2000: loss 1.299347
# iteration 1500 / 2000: loss 1.280309
# iteration 1600 / 2000: loss 1.201896
# iteration 1700 / 2000: loss 1.232251
# iteration 1800 / 2000: loss 1.204982
# iteration 1900 / 2000: loss 1.313645
# decay 0.999, lr 0.0005, C 1e-06
# Done 29 out of 36
# iteration 0 / 2000: loss 2.302569
# iteration 100 / 2000: loss 2.056510
# iteration 200 / 2000: loss 1.866267
# iteration 300 / 2000: loss 1.814108
# iteration 400 / 2000: loss 1.710691
# iteration 500 / 2000: loss 1.678038
# iteration 600 / 2000: loss 1.609925
# iteration 700 / 2000: loss 1.571177
# iteration 800 / 2000: loss 1.519633
# iteration 900 / 2000: loss 1.480608
# iteration 1000 / 2000: loss 1.551708
# iteration 1100 / 2000: loss 1.463065
# iteration 1200 / 2000: loss 1.427854
# iteration 1300 / 2000: loss 1.323867
# iteration 1400 / 2000: loss 1.390947
# iteration 1500 / 2000: loss 1.238226
# iteration 1600 / 2000: loss 1.332515
# iteration 1700 / 2000: loss 1.428056
# iteration 1800 / 2000: loss 1.272240
# iteration 1900 / 2000: loss 1.250111
# decay 0.999, lr 0.0005, C 5e-06
# Done 30 out of 36
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.031598
# iteration 200 / 2000: loss 1.847144
# iteration 300 / 2000: loss 1.744634
# iteration 400 / 2000: loss 1.629307
# iteration 500 / 2000: loss 1.643886
# iteration 600 / 2000: loss 1.611266
# iteration 700 / 2000: loss 1.598044
# iteration 800 / 2000: loss 1.589442
# iteration 900 / 2000: loss 1.464148
# iteration 1000 / 2000: loss 1.389523
# iteration 1100 / 2000: loss 1.448876
# iteration 1200 / 2000: loss 1.476861
# iteration 1300 / 2000: loss 1.370938
# iteration 1400 / 2000: loss 1.479778
# iteration 1500 / 2000: loss 1.346961
# iteration 1600 / 2000: loss 1.354040
# iteration 1700 / 2000: loss 1.439137
# iteration 1800 / 2000: loss 1.277285
# iteration 1900 / 2000: loss 1.349221
# decay 0.999, lr 0.0005, C 1e-05
# Done 31 out of 36
# iteration 0 / 2000: loss 2.302602
# iteration 100 / 2000: loss 2.058967
# iteration 200 / 2000: loss 1.885001
# iteration 300 / 2000: loss 1.856512
# iteration 400 / 2000: loss 1.724689
# iteration 500 / 2000: loss 1.612338
# iteration 600 / 2000: loss 1.602021
# iteration 700 / 2000: loss 1.594799
# iteration 800 / 2000: loss 1.563593
# iteration 900 / 2000: loss 1.635175
# iteration 1000 / 2000: loss 1.543581
# iteration 1100 / 2000: loss 1.483849
# iteration 1200 / 2000: loss 1.460483
# iteration 1300 / 2000: loss 1.532251
# iteration 1400 / 2000: loss 1.353259
# iteration 1500 / 2000: loss 1.376906
# iteration 1600 / 2000: loss 1.400183
# iteration 1700 / 2000: loss 1.331460
# iteration 1800 / 2000: loss 1.333854
# iteration 1900 / 2000: loss 1.320500
# decay 0.999, lr 0.0005, C 5e-05
# Done 32 out of 36
# iteration 0 / 2000: loss 2.302588
# iteration 100 / 2000: loss 2.121587
# iteration 200 / 2000: loss 1.954164
# iteration 300 / 2000: loss 1.800224
# iteration 400 / 2000: loss 1.638200
# iteration 500 / 2000: loss 1.735331
# iteration 600 / 2000: loss 1.537337
# iteration 700 / 2000: loss 1.594189
# iteration 800 / 2000: loss 1.533328
# iteration 900 / 2000: loss 1.424703
# iteration 1000 / 2000: loss 1.618689
# iteration 1100 / 2000: loss 1.475860
# iteration 1200 / 2000: loss 1.362900
# iteration 1300 / 2000: loss 1.387140
# iteration 1400 / 2000: loss 1.453648
# iteration 1500 / 2000: loss 1.331202
# iteration 1600 / 2000: loss 1.300805
# iteration 1700 / 2000: loss 1.351676
# iteration 1800 / 2000: loss 1.366179
# iteration 1900 / 2000: loss 1.248219
# decay 0.999, lr 0.0001, C 1e-06
# Done 33 out of 36
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.301302
# iteration 200 / 2000: loss 2.289048
# iteration 300 / 2000: loss 2.233992
# iteration 400 / 2000: loss 2.120917
# iteration 500 / 2000: loss 2.096417
# iteration 600 / 2000: loss 2.049579
# iteration 700 / 2000: loss 2.059627
# iteration 800 / 2000: loss 1.955329
# iteration 900 / 2000: loss 1.974858
# iteration 1000 / 2000: loss 1.800870
# iteration 1100 / 2000: loss 1.883823
# iteration 1200 / 2000: loss 1.810058
# iteration 1300 / 2000: loss 1.818277
# iteration 1400 / 2000: loss 1.750167
# iteration 1500 / 2000: loss 1.789769
# iteration 1600 / 2000: loss 1.731404
# iteration 1700 / 2000: loss 1.679941
# iteration 1800 / 2000: loss 1.803437
# iteration 1900 / 2000: loss 1.698661
# decay 0.999, lr 0.0001, C 5e-06
# Done 34 out of 36
# iteration 0 / 2000: loss 2.302521
# iteration 100 / 2000: loss 2.300830
# iteration 200 / 2000: loss 2.288718
# iteration 300 / 2000: loss 2.190644
# iteration 400 / 2000: loss 2.166787
# iteration 500 / 2000: loss 2.103927
# iteration 600 / 2000: loss 1.975475
# iteration 700 / 2000: loss 1.965544
# iteration 800 / 2000: loss 1.952227
# iteration 900 / 2000: loss 1.858254
# iteration 1000 / 2000: loss 1.923045
# iteration 1100 / 2000: loss 1.899912
# iteration 1200 / 2000: loss 1.783372
# iteration 1300 / 2000: loss 1.797420
# iteration 1400 / 2000: loss 1.825739
# iteration 1500 / 2000: loss 1.808379
# iteration 1600 / 2000: loss 1.773971
# iteration 1700 / 2000: loss 1.783944
# iteration 1800 / 2000: loss 1.722042
# iteration 1900 / 2000: loss 1.672792
# decay 0.999, lr 0.0001, C 1e-05
# Done 35 out of 36
# iteration 0 / 2000: loss 2.302572
# iteration 100 / 2000: loss 2.301337
# iteration 200 / 2000: loss 2.289184
# iteration 300 / 2000: loss 2.223242
# iteration 400 / 2000: loss 2.190463
# iteration 500 / 2000: loss 2.039367
# iteration 600 / 2000: loss 2.001154
# iteration 700 / 2000: loss 2.014735
# iteration 800 / 2000: loss 1.916521
# iteration 900 / 2000: loss 1.925536
# iteration 1000 / 2000: loss 1.911782
# iteration 1100 / 2000: loss 1.843896
# iteration 1200 / 2000: loss 1.779621
# iteration 1300 / 2000: loss 1.831777
# iteration 1400 / 2000: loss 1.734573
# iteration 1500 / 2000: loss 1.839771
# iteration 1600 / 2000: loss 1.775874
# iteration 1700 / 2000: loss 1.805439
# iteration 1800 / 2000: loss 1.686277
# iteration 1900 / 2000: loss 1.737280
# decay 0.999, lr 0.0001, C 5e-05
# Done 36 out of 36
# iteration 0 / 2000: loss 2.302550
# iteration 100 / 2000: loss 2.300946
# iteration 200 / 2000: loss 2.289420
# iteration 300 / 2000: loss 2.181139
# iteration 400 / 2000: loss 2.153281
# iteration 500 / 2000: loss 2.005852
# iteration 600 / 2000: loss 1.995847
# iteration 700 / 2000: loss 1.971095
# iteration 800 / 2000: loss 1.940351
# iteration 900 / 2000: loss 1.972324
# iteration 1000 / 2000: loss 1.772339
# iteration 1100 / 2000: loss 1.852398
# iteration 1200 / 2000: loss 1.789497
# iteration 1300 / 2000: loss 1.894619
# iteration 1400 / 2000: loss 1.696461
# iteration 1500 / 2000: loss 1.756600
# iteration 1600 / 2000: loss 1.795871
# iteration 1700 / 2000: loss 1.828006
# iteration 1800 / 2000: loss 1.744863
# iteration 1900 / 2000: loss 1.658130
# 0.95 0.00095 1e-05
# decay 9.500000e-01 lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.383571 val accuracy: 0.384000
# decay 9.500000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.386755 val accuracy: 0.387000
# decay 9.500000e-01 lr 1.000000e-04 reg 1.000000e-05 train accuracy: 0.383347 val accuracy: 0.377000
# decay 9.500000e-01 lr 1.000000e-04 reg 5.000000e-05 train accuracy: 0.384551 val accuracy: 0.390000
# decay 9.500000e-01 lr 5.000000e-04 reg 1.000000e-06 train accuracy: 0.539224 val accuracy: 0.498000
# decay 9.500000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.539347 val accuracy: 0.511000
# decay 9.500000e-01 lr 5.000000e-04 reg 1.000000e-05 train accuracy: 0.538714 val accuracy: 0.498000
# decay 9.500000e-01 lr 5.000000e-04 reg 5.000000e-05 train accuracy: 0.543735 val accuracy: 0.512000
# decay 9.500000e-01 lr 1.000000e-03 reg 1.000000e-06 train accuracy: 0.568755 val accuracy: 0.503000
# decay 9.500000e-01 lr 1.000000e-03 reg 5.000000e-06 train accuracy: 0.574918 val accuracy: 0.505000
# decay 9.500000e-01 lr 1.000000e-03 reg 1.000000e-05 train accuracy: 0.591020 val accuracy: 0.531000
# decay 9.500000e-01 lr 1.000000e-03 reg 5.000000e-05 train accuracy: 0.583204 val accuracy: 0.518000
# decay 9.900000e-01 lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.390653 val accuracy: 0.399000
# decay 9.900000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.389082 val accuracy: 0.396000
# decay 9.900000e-01 lr 1.000000e-04 reg 1.000000e-05 train accuracy: 0.390449 val accuracy: 0.382000
# decay 9.900000e-01 lr 1.000000e-04 reg 5.000000e-05 train accuracy: 0.390531 val accuracy: 0.388000
# decay 9.900000e-01 lr 5.000000e-04 reg 1.000000e-06 train accuracy: 0.542714 val accuracy: 0.509000
# decay 9.900000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.541755 val accuracy: 0.485000
# decay 9.900000e-01 lr 5.000000e-04 reg 1.000000e-05 train accuracy: 0.544082 val accuracy: 0.509000
# decay 9.900000e-01 lr 5.000000e-04 reg 5.000000e-05 train accuracy: 0.541408 val accuracy: 0.482000
# decay 9.900000e-01 lr 1.000000e-03 reg 1.000000e-06 train accuracy: 0.575755 val accuracy: 0.511000
# decay 9.900000e-01 lr 1.000000e-03 reg 5.000000e-06 train accuracy: 0.539408 val accuracy: 0.482000
# decay 9.900000e-01 lr 1.000000e-03 reg 1.000000e-05 train accuracy: 0.582755 val accuracy: 0.512000
# decay 9.900000e-01 lr 1.000000e-03 reg 5.000000e-05 train accuracy: 0.587082 val accuracy: 0.506000
# decay 9.990000e-01 lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.394367 val accuracy: 0.392000
# decay 9.990000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.391816 val accuracy: 0.386000
# decay 9.990000e-01 lr 1.000000e-04 reg 1.000000e-05 train accuracy: 0.390204 val accuracy: 0.397000
# decay 9.990000e-01 lr 1.000000e-04 reg 5.000000e-05 train accuracy: 0.391122 val accuracy: 0.386000
# decay 9.990000e-01 lr 5.000000e-04 reg 1.000000e-06 train accuracy: 0.543163 val accuracy: 0.493000
# decay 9.990000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.542592 val accuracy: 0.505000
# decay 9.990000e-01 lr 5.000000e-04 reg 1.000000e-05 train accuracy: 0.544755 val accuracy: 0.515000
# decay 9.990000e-01 lr 5.000000e-04 reg 5.000000e-05 train accuracy: 0.543347 val accuracy: 0.503000
# decay 9.990000e-01 lr 1.000000e-03 reg 1.000000e-06 train accuracy: 0.575776 val accuracy: 0.509000
# decay 9.990000e-01 lr 1.000000e-03 reg 5.000000e-06 train accuracy: 0.573673 val accuracy: 0.499000
# decay 9.990000e-01 lr 1.000000e-03 reg 1.000000e-05 train accuracy: 0.583286 val accuracy: 0.500000
# decay 9.990000e-01 lr 1.000000e-03 reg 5.000000e-05 train accuracy: 0.585755 val accuracy: 0.530000
# best validation accuracy achieved during cross-validation: 0.531000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.524

# %% [markdown]
# decay 9.500000e-01 lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.386796 val accuracy: 0.388000
# decay 9.500000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.387898 val accuracy: 0.378000
# decay 9.500000e-01 lr 1.000000e-04 reg 1.000000e-05 train accuracy: 0.383510 val accuracy: 0.382000
# decay 9.500000e-01 lr 1.000000e-04 reg 5.000000e-05 train accuracy: 0.384735 val accuracy: 0.382000
# decay 9.500000e-01 lr 5.000000e-04 reg 1.000000e-06 train accuracy: 0.543204 val accuracy: 0.499000
# decay 9.500000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.533612 val accuracy: 0.492000
# decay 9.500000e-01 lr 5.000000e-04 reg 1.000000e-05 train accuracy: 0.537571 val accuracy: 0.512000
# decay 9.500000e-01 lr 5.000000e-04 reg 5.000000e-05 train accuracy: 0.538531 val accuracy: 0.504000
# decay 9.500000e-01 lr 1.000000e-03 reg 1.000000e-06 train accuracy: 0.585531 val accuracy: 0.530000
# decay 9.500000e-01 lr 1.000000e-03 reg 5.000000e-06 train accuracy: 0.581633 val accuracy: 0.490000
# decay 9.500000e-01 lr 1.000000e-03 reg 1.000000e-05 train accuracy: 0.564082 val accuracy: 0.499000
# decay 9.500000e-01 lr 1.000000e-03 reg 5.000000e-05 train accuracy: 0.576735 val accuracy: 0.512000
# decay 9.900000e-01 lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.391082 val accuracy: 0.387000
# decay 9.900000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.390633 val accuracy: 0.393000
# decay 9.900000e-01 lr 1.000000e-04 reg 1.000000e-05 train accuracy: 0.390816 val accuracy: 0.387000
# decay 9.900000e-01 lr 1.000000e-04 reg 5.000000e-05 train accuracy: 0.392714 val accuracy: 0.384000
# decay 9.900000e-01 lr 5.000000e-04 reg 1.000000e-06 train accuracy: 0.540694 val accuracy: 0.500000
# decay 9.900000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.541000 val accuracy: 0.494000
# decay 9.900000e-01 lr 5.000000e-04 reg 1.000000e-05 train accuracy: 0.542041 val accuracy: 0.509000
# decay 9.900000e-01 lr 5.000000e-04 reg 5.000000e-05 train accuracy: 0.541306 val accuracy: 0.485000
# decay 9.900000e-01 lr 1.000000e-03 reg 1.000000e-06 train accuracy: 0.583265 val accuracy: 0.517000
# decay 9.900000e-01 lr 1.000000e-03 reg 5.000000e-06 train accuracy: 0.575673 val accuracy: 0.525000
# decay 9.900000e-01 lr 1.000000e-03 reg 1.000000e-05 train accuracy: 0.575245 val accuracy: 0.516000
# decay 9.900000e-01 lr 1.000000e-03 reg 5.000000e-05 train accuracy: 0.572571 val accuracy: 0.512000
# decay 9.990000e-01 lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.392367 val accuracy: 0.382000
# decay 9.990000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.392388 val accuracy: 0.383000
# decay 9.990000e-01 lr 1.000000e-04 reg 1.000000e-05 train accuracy: 0.393327 val accuracy: 0.386000
# decay 9.990000e-01 lr 1.000000e-04 reg 5.000000e-05 train accuracy: 0.391857 val accuracy: 0.385000
# decay 9.990000e-01 lr 5.000000e-04 reg 1.000000e-06 train accuracy: 0.544163 val accuracy: 0.509000
# decay 9.990000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.538714 val accuracy: 0.497000
# decay 9.990000e-01 lr 5.000000e-04 reg 1.000000e-05 train accuracy: 0.539204 val accuracy: 0.490000
# decay 9.990000e-01 lr 5.000000e-04 reg 5.000000e-05 train accuracy: 0.541143 val accuracy: 0.506000
# decay 9.990000e-01 lr 1.000000e-03 reg 1.000000e-06 train accuracy: 0.573490 val accuracy: 0.518000
# decay 9.990000e-01 lr 1.000000e-03 reg 5.000000e-06 train accuracy: 0.579469 val accuracy: 0.497000
# decay 9.990000e-01 lr 1.000000e-03 reg 1.000000e-05 train accuracy: 0.581776 val accuracy: 0.509000
# decay 9.990000e-01 lr 1.000000e-03 reg 5.000000e-05 train accuracy: 0.576551 val accuracy: 0.496000
# best validation accuracy achieved during cross-validation: 0.530000

# %% [markdown]
# decay 9.500000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.307429 val accuracy: 0.301000
# decay 9.500000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.460102 val accuracy: 0.458000
# decay 9.500000e-01 lr 1.000000e-03 reg 5.000000e-06 train accuracy: 0.502714 val accuracy: 0.494000
# decay 9.500000e-01 lr 5.000000e-03 reg 5.000000e-06 train accuracy: 0.100265 val accuracy: 0.087000
# decay 9.900000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.315122 val accuracy: 0.312000
# decay 9.900000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.461980 val accuracy: 0.450000
# decay 9.900000e-01 lr 1.000000e-03 reg 5.000000e-06 train accuracy: 0.477143 val accuracy: 0.463000
# decay 9.900000e-01 lr 5.000000e-03 reg 5.000000e-06 train accuracy: 0.100265 val accuracy: 0.087000
# decay 9.990000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.318408 val accuracy: 0.313000
# decay 9.990000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.462837 val accuracy: 0.463000
# decay 9.990000e-01 lr 1.000000e-03 reg 5.000000e-06 train accuracy: 0.489429 val accuracy: 0.464000
# decay 9.990000e-01 lr 5.000000e-03 reg 5.000000e-06 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.494000
#
# batch_size = 200
# num_iters = 1000
# hidden_size = 100

# %% [markdown]
# decay 9.900000e-01 lr 1.000000e-05 reg 1.000000e-07 train accuracy: 0.614388 val accuracy: 0.542000
# decay 9.900000e-01 lr 1.000000e-05 reg 1.000000e-06 train accuracy: 0.611694 val accuracy: 0.539000
# decay 9.900000e-01 lr 1.000000e-05 reg 5.000000e-06 train accuracy: 0.613735 val accuracy: 0.540000
# decay 9.900000e-01 lr 5.000000e-05 reg 1.000000e-07 train accuracy: 0.628612 val accuracy: 0.541000
# decay 9.900000e-01 lr 5.000000e-05 reg 1.000000e-06 train accuracy: 0.619735 val accuracy: 0.544000
# decay 9.900000e-01 lr 5.000000e-05 reg 5.000000e-06 train accuracy: 0.624490 val accuracy: 0.530000
# decay 9.900000e-01 lr 1.000000e-04 reg 1.000000e-07 train accuracy: 0.429551 val accuracy: 0.434000
# decay 9.900000e-01 lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.314347 val accuracy: 0.303000
# decay 9.900000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.386816 val accuracy: 0.379000
# decay 9.900000e-01 lr 5.000000e-04 reg 1.000000e-07 train accuracy: 0.596531 val accuracy: 0.529000
# decay 9.900000e-01 lr 5.000000e-04 reg 1.000000e-06 train accuracy: 0.512776 val accuracy: 0.478000
# decay 9.900000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.562857 val accuracy: 0.531000
# decay 9.990000e-01 lr 1.000000e-05 reg 1.000000e-07 train accuracy: 0.715102 val accuracy: 0.563000
# decay 9.990000e-01 lr 1.000000e-05 reg 1.000000e-06 train accuracy: 0.709612 val accuracy: 0.556000
# decay 9.990000e-01 lr 1.000000e-05 reg 5.000000e-06 train accuracy: 0.713061 val accuracy: 0.559000
# decay 9.990000e-01 lr 5.000000e-05 reg 1.000000e-07 train accuracy: 0.725286 val accuracy: 0.551000
# decay 9.990000e-01 lr 5.000000e-05 reg 1.000000e-06 train accuracy: 0.718816 val accuracy: 0.555000
# decay 9.990000e-01 lr 5.000000e-05 reg 5.000000e-06 train accuracy: 0.721857 val accuracy: 0.553000
# decay 9.990000e-01 lr 1.000000e-04 reg 1.000000e-07 train accuracy: 0.647184 val accuracy: 0.540000
# decay 9.990000e-01 lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.634367 val accuracy: 0.546000
# decay 9.990000e-01 lr 1.000000e-04 reg 5.000000e-06 train accuracy: 0.639653 val accuracy: 0.544000
# decay 9.990000e-01 lr 5.000000e-04 reg 1.000000e-07 train accuracy: 0.638429 val accuracy: 0.486000
# decay 9.990000e-01 lr 5.000000e-04 reg 1.000000e-06 train accuracy: 0.643571 val accuracy: 0.539000
# decay 9.990000e-01 lr 5.000000e-04 reg 5.000000e-06 train accuracy: 0.669714 val accuracy: 0.537000
# best validation accuracy achieved during cross-validation: 0.563000
#
# batch_size = 256
# num_iters = 1000
# hidden_size = 100
